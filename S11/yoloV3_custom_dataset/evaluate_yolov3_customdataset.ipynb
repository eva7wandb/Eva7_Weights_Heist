# %% [markdown]
# <a href="https://colab.research.google.com/github/eva7wandb/Eva7_Weights_Heist/blob/main/S11/yoloV3_custom_dataset/evaluate_yolov3_customdataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/askmuhsin/YoloV3
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 397, done.
# remote: Counting objects: 100% (235/235), done.
# remote: Compressing objects: 100% (232/232), done.
# remote: Total 397 (delta 2), reused 232 (delta 1), pack-reused 162
# Receiving objects: 100% (397/397), 13.83 MiB | 31.33 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
import gdown

# %%
url = 'https://drive.google.com/uc?id=1k7wSI9esLFbN976E4ClgybgJ3kmK7Ye8'
gdown.download(url, './final.pt', quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1k7wSI9esLFbN976E4ClgybgJ3kmK7Ye8
# To: /content/final.pt
# 100%|██████████| 251M/251M [00:01<00:00, 177MB/s]
# './final.pt'

# %%
! mkdir ./out_imgs

# %%
! python ./YoloV3/detect.py \
        --weights ./final.pt \
        --conf-thres 0.3 \
        --output ./out_imgs \
        --source ./YoloV3/test_images_dir/ \
        --cfg ./YoloV3/cfg/yolov3-custom.cfg \
        --names ./YoloV3/data/customdata/custom.names
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='./YoloV3/cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='./YoloV3/data/customdata/custom.names', output='./out_imgs', save_txt=False, source='./YoloV3/test_images_dir/', view_img=False, weights='./final.pt')
# Using CPU
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/3 YoloV3/test_images_dir/test_image_1.png: 384x512 2 vests, 1 masks, Done. (1.617s)
# image 2/3 YoloV3/test_images_dir/test_image_2.png: 320x512 2 hardhats, 2 vests, 3 masks, 1 bootss, Done. (1.200s)
# ...

# %%
import matplotlib.pyplot as plt
import cv2

# %%
plt.figure(figsize=(10, 10))
plt.imshow(
    cv2.cvtColor(
        cv2.imread('./out_imgs/test_image_3.png'), 
        cv2.COLOR_RGB2BGR
    )
)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(
    cv2.cvtColor(
        cv2.imread('./out_imgs/test_image_2.png'), 
        cv2.COLOR_RGB2BGR
    )
)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(
    cv2.cvtColor(
        cv2.imread('./out_imgs/test_image_1.png'), 
        cv2.COLOR_RGB2BGR
    )
)
